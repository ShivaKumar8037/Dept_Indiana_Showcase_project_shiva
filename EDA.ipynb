# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from geopy.geocoders import Nominatim
from geopy.exc import GeocoderTimedOut

# %%
data = pd.read_csv('companies.csv')

# %%
data.head()
# Out:
#                            Company  \
# 0           1 Brick Insurance, LLC
# 1                35 Realserv, Inc.
# 2            A. D. Baker & Company
# 3  A.F. Stevens & Associates, Inc.
# 4     Absolute Title Services, LLC
#
#                                            Violation        Date  \
# 0                                      No  Violation  2017-07-21
# 1                                 Failure to Respond  2009-05-21
# 2                   Lack of  Fitness/Trustworthiness  2000-12-13
# 3                      Misappropriation  of Premiums  2012-06-20
# 4  Failure  to enter RREAL transactions into data...  2016-06-30
#
#                          Action          Case Number  \
# 0            Vacate  Suspension  13740-AG15-0303-063
# 1         Suspension of License   7983-AG09-0515-094
# 2                     Probation    168-IDOI-CO01-022
# 3  License  permanently Revoked  11032-AG12-0321-020
# 4                 Fine  $810.00  15181-AG16-1531-125
#
#                                                 Link
# 0  https://www.in.gov/idoi/files/enforcement/1374...
# 1  https://www.in.gov/idoi/files/enforcement/7983...
# 2  https://www.in.gov/idoi/files/enforcement/168-...
# 3  https://www.in.gov/idoi/files/enforcement/1103...
# 4  https://www.in.gov/idoi/files/enforcement/1518...

# %%
# import pandas as pd
# from geopy.geocoders import Nominatim
# from geopy.exc import GeocoderTimedOut, GeocoderUnavailable
# import time

# # Function to handle geocoding with retries
# def do_geocode(company_name, attempt=1, max_attempts=5):
#     try:
#         return geolocator.geocode(company_name, timeout=10)  # Increased timeout to 10 seconds
#     except (GeocoderTimedOut, GeocoderUnavailable):
#         if attempt <= max_attempts:
#             time.sleep(1)  # Wait for 1 second before retrying
#             return do_geocode(company_name, attempt=attempt + 1)
#         raise

# # Initialize the geolocator with a unique User-Agent
# geolocator = Nominatim(user_agent="UniqasddsafsadfsafsdfsdueAppName_or_Email")  # Replace with your unique User-Agent

# # Load the CSV file
# companies_df = pd.read_csv("companies.csv")

# # Define new columns for latitude and longitude
# companies_df['Latitude'] = None
# companies_df['Longitude'] = None

# # Iterate over the company names and get coordinates
# for index, row in companies_df.iterrows():
#     company_name = row['Company']
#     location = do_geocode(company_name)
#     if location:
#         companies_df.at[index, 'Latitude'] = location.latitude
#         companies_df.at[index, 'Longitude'] = location.longitude

#     # Delay between requests to avoid hitting rate limits
#     time.sleep(1)  # Delay for 1 second

# # Save the dataframe with new columns
# companies_df.to_csv("updated_companies.csv", index=False)

# %%
data['Date'] = pd.to_datetime(data['Date'])

# %%
Companies_23 = data[data['Date'].dt.year == 2023]

# %%
Companies_23
# Out:
#                                        Company  \
# 6                          Accurate Group, LLC
# 7       Acrisure National Lender Services, LLC
# 8    Acuity National Real Estate Solutions LLC
# 10                    Adroit Health Group, LLC
# 11                         Advantage Title LLC
# 18               A-Max Insurance Services, LLC
# 29                America's Settlement Company
# 69                       Chicago Title Co. LLC
# 74                        ClearEdge Title, Inc
# 75                              Closeline, LLC
# 253                 Rise & Shine Services, LLC
# 270       Southwestern Indiana Land Title, Inc
# 276                      Stewart Title Company
# 291          Title Alliance of Indy Metro, LLC
# 299                     Transfer National, Inc
# 301                 Trident Life Services, Inc
# 352               AMC Settlement Services, LLC
# 362               America's Settlement Company
# 375                 Avenue 365 Lender Services
# 383            Better Settlement Services, LLC
# 417     Conway Alternative Risk Solutions, LLC
# 421                Cypress Risk Management LLC
# 432           Empower Settlement Services, LLC
# 592                     RKM Insurance Services
# 601                          Seguro Medico LLC
# 627                Title Clearing & Escrow LLC
# 635                       Trademark Title, Inc
# 636                      Transtar National Inc
# 653                   Vantage Point Title, Inc
# 655                             Vetinsure, LLC
# 656                          Victory Title Inc
# 665   YZ Financial Services and Insurance, LLC
#
#                                              Violation       Date  \
# 6              Failed  to enter 105 RREAL transactions 2023-04-05
# 7    Failure to enter RREAL transactions into database 2023-09-26
# 8             Failure  to enter 489 RREAL transactions 2023-06-08
# 10                                 License  Revocation 2023-11-16
# 11                Failure  to input RREAL transactions 2023-03-16
# 18                               Administration Action 2023-10-19
# 29   Failure  to enter RREAL transactions into data... 2023-08-03
# 69   Failure to enter RREAL transactions into database 2023-09-26
# 74   Failure  to enter RREAL transactions into data... 2023-11-29
# 75   Failure  to enter RREAL transactions into data... 2023-11-02
# 253                              Failure  to pay taxes 2023-04-20
# 270           Failure  to enter 277 RREAL transactions 2023-02-21
# 276           Failure  to enter 617 RREAL transactions 2023-05-04
# 291           Failure  to enter 493 RREAL transactions 2023-02-16
# 299            Failed  to enter 495 RREAL transactions 2023-02-16
# 301             Failure  to report other states action 2023-05-09
# 352            Failure  to enter 52 RREAL transactions 2023-05-04
# 362  Failure to enter RREAL transactions into database 2023-08-03
# 375  Failure to enter RREAL transactions into database 2023-08-03
# 383  Failure  to enter RREAL transactions into data... 2023-11-16
# 417  Failure  to report 2 admin actions in a timely... 2023-03-30
# 421                             No home  state license 2023-05-18
# 432  Failure  to enter RREAL transactions into data... 2023-11-02
# 592                  Failure  to Disclose Admin Action 2023-06-29
# 601                                  Suspension  order 2023-03-14
# 627             Failed  to enter 72 RREAL transactions 2023-04-05
# 635           Failure  to enter 749 RREAL transactions 2023-04-27
# 636               Failure  to input RREAL transactions 2023-02-16
# 653                Failed  to input RREAL transactions 2023-03-16
# 655                   License  Denied by another state 2023-09-19
# 656           Failure  to enter 155 RREAL transactions 2023-04-24
# 665          Failure to Disclose Administrative Action 2023-09-26
#
#                        Action           Case Number  \
# 6       $1,450  civil penalty   21897-AG23-0224-040
# 7         $1400 Civil Penalty   22451-AG23-0630-091
# 8                 $5290  fine   21896-AG23-0322-057
# 10     $750.00  Civil Penalty   21921-AG23-1019-143
# 11               $4,530  fine   21894-AG23-0202-019
# 18          2 Year  Probation   22490-AG23-0620-083
# 29       $2830  Civil Penalty   22223-AG23-0403-062
# 69                $16070 fine   22235-AG23-0719-099
# 74     $2640.00 Civil Penalty   22449-AG23-1005-140
# 75     $1820.00 Civil Penalty   22448-AG23-0913-127
