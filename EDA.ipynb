# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from geopy.geocoders import Nominatim
from geopy.exc import GeocoderTimedOut

# %%
data = pd.read_csv('companies.csv')

# %%
data.head()
# Out:
#                            Company  \
# 0           1 Brick Insurance, LLC
# 1                35 Realserv, Inc.
# 2            A. D. Baker & Company
# 3  A.F. Stevens & Associates, Inc.
# 4     Absolute Title Services, LLC
#
#                                            Violation        Date  \
# 0                                      No  Violation  2017-07-21
# 1                                 Failure to Respond  2009-05-21
# 2                   Lack of  Fitness/Trustworthiness  2000-12-13
# 3                      Misappropriation  of Premiums  2012-06-20
# 4  Failure  to enter RREAL transactions into data...  2016-06-30
#
#                          Action          Case Number  \
# 0            Vacate  Suspension  13740-AG15-0303-063
# 1         Suspension of License   7983-AG09-0515-094
# 2                     Probation    168-IDOI-CO01-022
# 3  License  permanently Revoked  11032-AG12-0321-020
# 4                 Fine  $810.00  15181-AG16-1531-125
#
# ...

# %%
# import pandas as pd
# from geopy.geocoders import Nominatim
# from geopy.exc import GeocoderTimedOut, GeocoderUnavailable
# import time

# # Function to handle geocoding with retries
# def do_geocode(company_name, attempt=1, max_attempts=5):
#     try:
#         return geolocator.geocode(company_name, timeout=10)  # Increased timeout to 10 seconds
#     except (GeocoderTimedOut, GeocoderUnavailable):
#         if attempt <= max_attempts:
#             time.sleep(1)  # Wait for 1 second before retrying
#             return do_geocode(company_name, attempt=attempt + 1)
#         raise

# # Initialize the geolocator with a unique User-Agent
# geolocator = Nominatim(user_agent="UniqasddsafsadfsafsdfsdueAppName_or_Email")  # Replace with your unique User-Agent

# # Load the CSV file
# companies_df = pd.read_csv("companies.csv")

# # Define new columns for latitude and longitude
# companies_df['Latitude'] = None
# companies_df['Longitude'] = None

# # Iterate over the company names and get coordinates
# for index, row in companies_df.iterrows():
#     company_name = row['Company']
#     location = do_geocode(company_name)
#     if location:
#         companies_df.at[index, 'Latitude'] = location.latitude
#         companies_df.at[index, 'Longitude'] = location.longitude

#     # Delay between requests to avoid hitting rate limits
#     time.sleep(1)  # Delay for 1 second

# # Save the dataframe with new columns
# companies_df.to_csv("updated_companies.csv", index=False)

# %%
data['Date'] = pd.to_datetime(data['Date'])

# %%
Companies_23 = pd.read_csv('Modified_Companies_23.csv')

# %%
Companies_23
# Out:
#                                       Company  \
# 0                         Accurate Group, LLC
# 1      Acrisure National Lender Services, LLC
# 2   Acuity National Real Estate Solutions LLC
# 3                    Adroit Health Group, LLC
# 4                         Advantage Title LLC
# 5               A-Max Insurance Services, LLC
# 6                America's Settlement Company
# 7                       Chicago Title Co. LLC
# 8                        ClearEdge Title, Inc
# 9                              Closeline, LLC
# 10                 Rise & Shine Services, LLC
# 11       Southwestern Indiana Land Title, Inc
# 12                      Stewart Title Company
# 13          Title Alliance of Indy Metro, LLC
# 14                     Transfer National, Inc
# 15                 Trident Life Services, Inc
# 16               AMC Settlement Services, LLC
# 17               America's Settlement Company
# 18                 Avenue 365 Lender Services
# ...

# %%
import folium

# Creating a base map using Folium
map = folium.Map(location=[40.7128, -74.0060], zoom_start=4)  # Using New York City coordinates as the center for the map

# Adding markers for each company
for _, row in Companies_23.iterrows():
    tooltip = f"{row['Company']}\nViolation: {row['Violation']}\nDate: {row['Date']}\nAction: {row['Action']}"
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=tooltip,
        icon=folium.Icon(icon="info-sign")
    ).add_to(map)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...
